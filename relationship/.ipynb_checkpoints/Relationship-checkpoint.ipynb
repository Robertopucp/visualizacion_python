# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
macro = pd.read_csv("data/macroeconomia.csv")
macro
# Out:
#        Fecha  IPM   TC  RIN        IPC  DIPM  DTC  DRIN  INFLATION
# 0     2003-1  2.8  1.3   9.2  4.418276    14    1    13   2.256905
# 1     2003-2  2.9  1.3   9.2  4.422953    12    0    13   2.763964
# 2     2003-3  2.8  1.2   9.2  4.434069     8    1    17   3.338574
# 3     2003-4  2.8  1.2   9.2  4.433560     2    1    14   2.561032
# 4     2003-5  2.9  1.2   9.2  4.433240     7    1    12   2.390278
# ..       ...  ...  ...   ...       ...   ...  ...   ...        ...
# 199   2019-8  3.7  1.2  11.1  4.883685     4    3    12   2.019200
# 200   2019-9  3.7  1.2  11.1  4.883749     8    1    16   1.834084
# 201  2019-10  3.7  1.2  11.1  4.884855     0    1    15   1.863098
# 202  2019-11  3.7  1.2  11.1  4.885944     1    0    12   1.849586
# 203  2019-12  3.7  1.2  11.1  4.888087     3    0    13   1.882265
#
# [204 rows x 9 columns]

# %%
#macro['month'] = macro['Fecha'].strftime("%Y-%M")
macro['DATE']  = pd.to_datetime(macro['Fecha']).dt.strftime('%Y-%m')
macro
# Out:
#        Fecha  IPM   TC  RIN        IPC  DIPM  DTC  DRIN  INFLATION     DATE
# 0     2003-1  2.8  1.3   9.2  4.418276    14    1    13   2.256905  2003-01
# 1     2003-2  2.9  1.3   9.2  4.422953    12    0    13   2.763964  2003-02
# 2     2003-3  2.8  1.2   9.2  4.434069     8    1    17   3.338574  2003-03
# 3     2003-4  2.8  1.2   9.2  4.433560     2    1    14   2.561032  2003-04
# 4     2003-5  2.9  1.2   9.2  4.433240     7    1    12   2.390278  2003-05
# ..       ...  ...  ...   ...       ...   ...  ...   ...        ...      ...
# 199   2019-8  3.7  1.2  11.1  4.883685     4    3    12   2.019200  2019-08
# 200   2019-9  3.7  1.2  11.1  4.883749     8    1    16   1.834084  2019-09
# 201  2019-10  3.7  1.2  11.1  4.884855     0    1    15   1.863098  2019-10
# 202  2019-11  3.7  1.2  11.1  4.885944     1    0    12   1.849586  2019-11
# 203  2019-12  3.7  1.2  11.1  4.888087     3    0    13   1.882265  2019-12
#
# [204 rows x 10 columns]

# %%
sns.relplot(x="DATE", y="IPM", kind="line", data=macro)
